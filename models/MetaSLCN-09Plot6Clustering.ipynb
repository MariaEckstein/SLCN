# %% [markdown]
# # Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import plotnine as gg
gg.theme_set(gg.theme_classic)
import seaborn as sns
# import sklearn.linear_model as sklin
# import sklearn.metrics as skmet
# import sklearn.model_selection as skmod
# import sklearn.preprocessing as skprep

# %%
from Functions import get_ages_cols, name_from_index, get_category_dict, get_param_names

# %% [markdown]
# ## Directories etc.

# %%
data_save_path = "C:/Users/maria/MEGAsync/SLCNdata/Meta/all_data"
plot_save_path = "C:/Users/maria/MEGAsync/SLCN/MetaSLCNPlots"
if not os.path.exists(plot_save_path):
    os.makedirs(plot_save_path)

# %% [markdown]
# # Get data

# %%
all_data = pd.read_csv(os.path.join(data_save_path, 'all_data.csv'), index_col=0)
all_data_z = pd.read_csv(os.path.join(data_save_path, 'all_data_z.csv'), index_col=0)
all_data_long = pd.read_csv(os.path.join(data_save_path, 'all_data_long.csv'), index_col=0)
all_data_long_z = pd.read_csv(os.path.join(data_save_path, 'all_data_long_z.csv'), index_col=0)
# fit_pd_all = pd.read_csv(os.path.join(data_save_path, 'fit_pd_all.csv'), index_col=0)
ages_dir = "C:/Users/maria/MEGAsync/SLCNdata/SLCNinfo2.csv"
ages = pd.read_csv(os.path.join(ages_dir))

# %%
param_cols = list(set([c for c in all_data.columns for p in get_param_names() if p in c]))
acc_rt_cols = [c for c in all_data.columns if ('ACC' in c) or ('RT' in c)]
ages_cols = get_ages_cols()
category_dict = get_category_dict()

# %% [markdown]
# # Dendrograms

# %%
all_data_d = all_data.copy()
all_data_d['PreciseYrs'] = all_data_d['PreciseYrs'].round()
all_data_d = all_data_d.set_index('PreciseYrs')
all_data_d
# Out:
#              ID        BMI     sex       meanT   PDS age_group_ PDS_group_  \
# PreciseYrs
# 9.0          17  18.200751  Female         NaN  2.50      08-10      2_mid
# 13.0         18  16.157863  Female         NaN  2.25      10-13    1_early
# 15.0         20  17.433768    Male  120.649667  2.80      13-15     3_late
# 16.0         22  22.709959    Male  147.334443  3.00      15-17     3_late
# 11.0         23  15.147686    Male   27.712900  1.00      10-13      0_pre
# ...         ...        ...     ...         ...   ...        ...        ...
# 22.0        465        NaN  Female         NaN   NaN     2Stud.    4_Stud.
# 20.0        466        NaN    Male         NaN   NaN     2Stud.    4_Stud.
# 19.0        467        NaN  Female         NaN   NaN     2Stud.    4_Stud.
# 22.0        468        NaN  Female         NaN   NaN     2Stud.    4_Stud.
# 19.0        469        NaN  Female         NaN   NaN     2Stud.    4_Stud.
#
#            T_group_   bf_ACC    bf_RT  ...    ps_LWS  ps_criterion_trial  \
# PreciseYrs                             ...
# 9.0             NaN  0.56667  1.33950  ...  1.000000            3.666667
# 13.0            NaN  0.80000  1.19270  ...  0.904762            4.222222
# 15.0         3_100%  0.85000  0.99265  ...  0.950000            4.000000
# 16.0         3_100%  0.73333  1.51800  ...  0.933333            4.250000
# 11.0          1_50%  0.81667  1.62240  ...  1.000000            3.714286
# ...             ...      ...      ...  ...       ...                 ...
# 22.0        4_Stud.  0.74167  1.11640  ...  1.000000            3.625000
# 20.0        4_Stud.  0.60833  0.87618  ...  1.000000            3.750000
# 19.0        4_Stud.  0.80000  1.29200  ...  1.000000            4.000000
# 22.0        4_Stud.  0.71667  2.12680  ...  1.000000            5.000000
# 19.0        4_Stud.  0.73333  1.13650  ...  1.000000            4.375000
#
#             bf_ACC_first3trials  bf_asymptote  bf_learning_slope  \
# PreciseYrs
# 9.0                    0.333333       0.59077          -0.053115
# 13.0                   0.250000       0.96463          -2.393200
# 15.0                   0.500000       0.98363          -2.137900
# 16.0                   0.416667       0.82375          -1.937400
# 11.0                   0.666667       0.88317          -1.730200
# ...                         ...           ...                ...
# 22.0                   0.666667       0.75862           3.626000
# 20.0                   0.583333       0.63033          -1.718600
# 19.0                   0.750000       0.80872          -0.662550
# 22.0                   0.500000       0.73918          -0.539960
# 19.0                   0.500000       0.77005          -1.085500
#
#             bf_intercept   bf_prew  bf_delay  ps_1_over_beta  ps_persev
# PreciseYrs
# 9.0             0.255267 -0.318745 -0.108595        0.624020   0.041755
# 13.0            1.930379  1.195528 -0.120319        0.288301   0.266281
# 15.0            2.352541  1.329053 -0.168739        0.109845   0.340698
# 16.0            1.152193  0.528728 -0.163958        0.518236   0.262544
# 11.0            1.548147  0.690841 -0.190590        0.431391   0.136008
# ...                  ...       ...       ...             ...        ...
# 22.0            1.238689  0.644662 -0.135437        0.197086   0.380321
# 20.0            0.566666  0.213814 -0.238006        0.155358   0.181026
# 19.0            1.276838  0.174681 -0.118256        0.253774   0.170041
# 22.0            0.941660  0.174725 -0.110450        0.272589   0.419072
# 19.0            1.048152  0.325551 -0.082799        0.444296   0.397656
#
# [247 rows x 70 columns]

# %%
sns.clustermap(all_data_d[acc_rt_cols].dropna(), z_score=1)
plt.savefig(os.path.join(plot_save_path, '6_DendrogramAccRt.png'))
sns.clustermap(all_data_d[param_cols].dropna(), z_score=1)
plt.savefig(os.path.join(plot_save_path, '6_DendrogramPar.png'))
sns.clustermap(all_data_d.dropna(), z_score=1)
plt.savefig(os.path.join(plot_save_path, '6_DendrogramBeh.png'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-581f8bf0a7d8> in <module>
#       3 sns.clustermap(all_data_d[param_cols].dropna(), z_score=1)
#       4 plt.savefig(os.path.join(plot_save_path, '6_DendrogramPar.png'))
# ----> 5 sns.clustermap(all_data_d.dropna(), z_score=1)
#       6 plt.savefig(os.path.join(plot_save_path, '6_DendrogramBeh.png'))
#
# ~\Anaconda3\envs\notebooks\lib\site-packages\seaborn\matrix.py in clustermap(data, pivot_kws, method, metric, z_score, standard_scale, figsize, cbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, row_colors, col_colors, mask, dendrogram_ratio, colors_ratio, cbar_pos, tree_kws, **kwargs)
#    1385                           colors_ratio=colors_ratio, cbar_pos=cbar_pos)
#    1386
# -> 1387     return plotter.plot(metric=metric, method=method,
#    1388                         colorbar_kws=cbar_kws,
#    1389                         row_cluster=row_cluster, col_cluster=col_cluster,
#
# ~\Anaconda3\envs\notebooks\lib\site-packages\seaborn\matrix.py in plot(self, metric, method, colorbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, tree_kws, **kws)
#    1204         colorbar_kws = {} if colorbar_kws is None else colorbar_kws
#    1205
# -> 1206         self.plot_dendrograms(row_cluster, col_cluster, metric, method,
#    1207                               row_linkage=row_linkage, col_linkage=col_linkage,
#    1208                               tree_kws=tree_kws)
#
# ~\Anaconda3\envs\notebooks\lib\site-packages\seaborn\matrix.py in plot_dendrograms(self, row_cluster, col_cluster, metric, method, row_linkage, col_linkage, tree_kws)
#    1049         # Plot the row dendrogram
#    1050         if row_cluster:
# -> 1051             self.dendrogram_row = dendrogram(
#    1052                 self.data2d, metric=metric, method=method, label=False, axis=0,
#    1053                 ax=self.ax_row_dendrogram, rotate=True, linkage=row_linkage,
#
# ~\Anaconda3\envs\notebooks\lib\site-packages\seaborn\matrix.py in dendrogram(data, linkage, axis, label, metric, method, rotate, tree_kws, ax)
#     768
#     769     """
# --> 770     plotter = _DendrogramPlotter(data, linkage=linkage, axis=axis,
#     771                                  metric=metric, method=method,
#     772                                  label=label, rotate=rotate)
#
# ~\Anaconda3\envs\notebooks\lib\site-packages\seaborn\matrix.py in __init__(self, data, linkage, metric, method, axis, label, rotate)
#     582
#     583         if linkage is None:
# --> 584             self.linkage = self.calculated_linkage
#     585         else:
#     586             self.linkage = linkage
#
# ~\Anaconda3\envs\notebooks\lib\site-packages\seaborn\matrix.py in calculated_linkage(self)
#     649                 warnings.warn(msg)
#     650
# --> 651         return self._calculate_linkage_scipy()
#     652
#     653     def calculate_dendrogram(self):
#
# ~\Anaconda3\envs\notebooks\lib\site-packages\seaborn\matrix.py in _calculate_linkage_scipy(self)
#     617
#     618     def _calculate_linkage_scipy(self):
# --> 619         linkage = hierarchy.linkage(self.array, method=self.method,
#     620                                     metric=self.metric)
#     621         return linkage
#
# ~\Anaconda3\envs\notebooks\lib\site-packages\scipy\cluster\hierarchy.py in linkage(y, method, metric, optimal_ordering)
#    1055
#    1056     if not np.all(np.isfinite(y)):
# -> 1057         raise ValueError("The condensed distance matrix must contain only "
#    1058                          "finite values.")
#    1059
#
# ValueError: The condensed distance matrix must contain only finite values.

# %% [markdown]
# # tSNE

# %%
# Show participants in 2D space
tsne_dat = TSNE(n_components=2).fit_transform(z_dat.dropna())
index = all_data.reset_index().drop(columns=ages_cols[1:]).dropna().ID
tsne_pd = pd.DataFrame(tsne_dat, columns=['tSNE1', 'tSNE2'], index=index).reset_index()
tsne_pd = tsne_pd.merge(ages[['ID', 'PreciseYrs', 'Gender', 'meanT']])

# %%
gg.options.figure_size = (5, 4)
g = (gg.ggplot(tsne_pd, gg.aes('tSNE1', 'tSNE2', color='PreciseYrs'))
 + gg.geom_point()
)
g.save(os.path.join(plot_save_path, '4TsneParticipants.png'))
g

# %%
tsne_long = tsne_pd.melt(id_vars=['ID', 'PreciseYrs', 'Gender', 'meanT'])
g = (gg.ggplot(tsne_long, gg.aes('PreciseYrs', 'value'))
 + gg.geom_point()
 + gg.geom_smooth()
 + gg.facet_grid('~ variable')
)
g.save(os.path.join(plot_save_path, '4TsneParticipants_.png'))
g

# %%
# Show measures in 2D space
tsne_dat = TSNE(n_components=2).fit_transform(z_dat.dropna().T)
tsne_pd = pd.DataFrame(tsne_dat, columns=['tSNE1', 'tSNE2'], index=z_dat.columns).reset_index()
tsne_pd['task'] = tsne_pd['index'].apply(lambda x : x[:2])
tsne_pd['param_name'] = tsne_pd['index'].apply(name_from_index)
tsne_pd['ACC_RT'] = tsne_pd['index'].apply(name_from_index, names=['ACC', 'RT'])
tsne_pd['param_bool'] = tsne_pd['index'].apply(bool_from_index)
tsne_pd

# %%
gg.options.figure_size = (5, 4)
g = (gg.ggplot(tsne_pd, gg.aes('tSNE1', 'tSNE2', color='task'))
 + gg.geom_point()
)
g.save(os.path.join(plot_save_path, '4TsneFeaturesBeh_task.png'))
g

# %% [markdown]
# # Transforming RLWM regression weights

# %%
all_data['rl_lrn-fix'].describe()
all_data['rl_lrn-fix_sig'].describe()
zscore(all_data['rl_lrn-fix']).describe()

# %%
x = np.arange(-30, 30, 0.1)
# x = np.arange(-10, 10, 0.01)
# dat = pd.DataFrame({'x': x, 'y': 3 *sigmoid(x/3)})
# dat = pd.DataFrame({'x': x, 'y': sigmoid(x)})
dat = pd.DataFrame({'x': x, 'y': sigmoid(zscore(x))})
dat
(gg.ggplot(dat, gg.aes('x', 'y')) +
 gg.geom_point()
)

# %%
# all_data['rl_lrn-fix_sig'] = sigmoid(zscore(all_data['rl_lrn-fix']))
all_data['rl_lrn-fix_sig'] = sigmoid(all_data['rl_lrn-fix'])
# all_data['rl_lrn-fix_sig'] = 50 * sigmoid(all_data['rl_lrn-fix'] / 50)
# all_data['rl_lrn-fix_sig'] = all_data['rl_lrn-fix_sig'].median() * sigmoid(all_data['rl_lrn-fix'] / all_data['rl_lrn-fix_sig'].median())

(gg.ggplot(all_data, gg.aes('rl_lrn-fix', 'rl_lrn-fix_sig')) +
 gg.geom_point()
)

# %%
dat = all_data#[all_data['rl_lrn-fix'] < 50]
(gg.ggplot(dat, gg.aes('PreciseYrs', 'rl_lrn-fix_sig'))
 + gg.geom_point()
 + gg.geom_smooth()
)

# %%
dat = all_data[all_data['rl_lrn-fix'] < 50]
(gg.ggplot(dat, gg.aes('PreciseYrs', 'rl_lrn-fix'))
 + gg.geom_point()
 + gg.geom_smooth()
)

# %%
(gg.ggplot(all_data, gg.aes('PreciseYrs', 'rl_lrn-ns'))
 + gg.geom_point()
)

# %%
(gg.ggplot(all_data, gg.aes('PreciseYrs', 'rl_lrn-pcor'))
 + gg.geom_point()
)

# %%
(gg.ggplot(all_data, gg.aes('PreciseYrs', 'rl_lrn-pinc'))
 + gg.geom_point()
)
